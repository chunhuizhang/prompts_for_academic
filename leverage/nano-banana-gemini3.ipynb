# %% [markdown]
# > 视觉化理解（Understanding）和呈现（Presentation）的时代。
# - blog(s)/book(s)/paper(s)

# %% [markdown]
# ### NotebookLM

# %% [markdown]
# - infographic（信息图）
#     - Make an infographic explaining Einstein's theory of General Relativity suitable for a 6th grader in Chinese
# - slide deck：注意有设置选项；
#     - (rich) Images as PPT/PDF
#         - 分辨率以及生图能力的提升，一个页面内可以承载的信息非常非常多，可能只需要一个风格化提示，
#     - 只需要关心内容（content/elements），大致的风格（哆啦A梦。。。），美学/布局/字体颜色底层模型可以 handle；
# - cases
#     - https://notebooklm.google.com/notebook/63956825-7745-447a-be2e-0571c4522a30?artifactId=485f9a4c-e53c-46ff-85d2-7669d24bed36
#         - https://arpitbhayani.me/blogs/how-llm-inference-works
#     - https://notebooklm.google.com/notebook/c6bf2286-a570-4769-8127-6759a2a24f3c
# ```
# # 一张图
# Take this paper and create an image of a whiteboard with a summary of it using diagrams, arrows, bubbles, colors and captions explaining the core idea [in Chinese]
#
# # 板书 https://www.bilibili.com/video/BV1BHUwBdEpq
# Take the text from x post and transform in the image of professor whiteboard image: diagrams, arrows, boxes, and captions explaining the core idea visually. Use colors as well.
# 把这篇论文转换成教授板书照片的样子：包含图表、箭头、方框和说明文字，从视觉上阐释核心思想。同时笔迹使用多种颜色。
#
# # 直接绘制 poster
# 为这篇论文生成学术会议用的 poster。
#
# # 高质量板书 + （2k/4k）分辨率输出
# Generate a high-resolution photograph of a clean, well-lit whiteboard covered with accurate technical notes summarizing the provided paper.
# OBJECTIVE:
# Produce a realistic whiteboard used by a senior AI researcher teaching the topic.
# All handwriting must be clean, concise, and fully based on the provided content.
# STRICT CONTENT RULES:
# - Absolutely NO gibberish, fake words, misspellings, or random symbols.
# - All terms MUST come from the provided text.
# - No hallucinated equations or invented labels.
# - Summaries must be short, correct, and high-level.
#
# CONTENT TO SUMMARIZE (use ONLY this content).
#
# # 多图 ppt
# Claude-style teaching slide: clean white background, hand-drawn black marker text, flat colors only. Pack every concept into crisp boxes, arrows, and mini-diagrams. Central idea large; all subpoints placed around it with clear labels. High-clarity, professor-sketch aesthetic—structured, dense, all content preserved.
# ```

# %% [markdown]
# - 漫画（https://zhuanlan.zhihu.com/p/1975730596534830124）
#     - 哆啦A梦，柯南，蜡笔小新
# ```
# 参考《哆啦A梦》的漫画风格，绘制哆啦A梦教大雄学习这篇论文的核心内容，中文对白，彩色画面。
# 参考《哆啦A梦》的漫画风格，绘制哆啦A梦教大雄学习这篇论文的核心内容，中文对白，彩色画面，特别注意中文文字生成的正确性。
#
# 参考《大侦探福尔摩斯》的漫画风格，绘制福尔摩斯和华生讨论学习这篇论文的核心内容，中文对白，彩色画面，特别注意中文文字生成的正确性。
#
# # 抽丝剥茧/推理的感觉
# 参考日本《名侦探柯南》的漫画风格，绘制这一系列rlvr工作的核心内容、演进以及学术讨论，中文对白，彩色画面，特别注意中文文字生成的正确性。
# ```
#
# - 单图：某某风格，X格漫画；

# %% [markdown]
# ### 风格

# %% [markdown]
# 1. 时尚涂鸦风格 Chic Doodle Style
# 2. 新野兽派风格 Neo-Brutalism Style
# 3. 现代插画风格 Flat 2.0 / Corporate Memphis Style
# 4. 经典手绘风格 Hand-Drawn Sketchnote Style
# 5. 艺术拼贴的混合媒介美学风格 Collage / Mixed Media Style
# 6.  未来感的空间界面美学风格 Glassmorphism 2.0 / Spatial UI Style

# %% [markdown]
# ### canvas & web 前端

# %% [markdown]
# - 滚动元素/鼠标 cursor 互动，平面化插图设计风格
